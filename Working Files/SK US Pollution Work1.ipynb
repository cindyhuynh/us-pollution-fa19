# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
raw_data = pd.read_csv(r'pollution_us_2000_2016.csv')

# %%
raw_data.head(8)
# Out:
#    Unnamed: 0  State Code  County Code  Site Num  \
# 0           0           4           13      3002
# 1           1           4           13      3002
# 2           2           4           13      3002
# 3           3           4           13      3002
# 4           4           4           13      3002
# 5           5           4           13      3002
# 6           6           4           13      3002
# 7           7           4           13      3002
#
#                                    Address    State    County     City  \
# 0  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 5  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 6  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 7  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
#
#    Date Local          NO2 Units  ...          SO2 Units  SO2 Mean  \
# 0  2000-01-01  Parts per billion  ...  Parts per billion  3.000000
# 1  2000-01-01  Parts per billion  ...  Parts per billion  3.000000
# 2  2000-01-01  Parts per billion  ...  Parts per billion  2.975000
# 3  2000-01-01  Parts per billion  ...  Parts per billion  2.975000
# 4  2000-01-02  Parts per billion  ...  Parts per billion  1.958333
# 5  2000-01-02  Parts per billion  ...  Parts per billion  1.958333
# 6  2000-01-02  Parts per billion  ...  Parts per billion  1.937500
# 7  2000-01-02  Parts per billion  ...  Parts per billion  1.937500
#
#    SO2 1st Max Value  SO2 1st Max Hour SO2 AQI           CO Units   CO Mean  \
# 0                9.0                21    13.0  Parts per million  1.145833
# 1                9.0                21    13.0  Parts per million  0.878947
# 2                6.6                23     NaN  Parts per million  1.145833
# 3                6.6                23     NaN  Parts per million  0.878947
# 4                3.0                22     4.0  Parts per million  0.850000
# 5                3.0                22     4.0  Parts per million  1.066667
# 6                2.6                23     NaN  Parts per million  0.850000
# 7                2.6                23     NaN  Parts per million  1.066667
#
#    CO 1st Max Value  CO 1st Max Hour CO AQI
# 0               4.2               21    NaN
# 1               2.2               23   25.0
# 2               4.2               21    NaN
# 3               2.2               23   25.0
# 4               1.6               23    NaN
# 5               2.3                0   26.0
# 6               1.6               23    NaN
# 7               2.3                0   26.0
#
# [8 rows x 29 columns]

# %%
raw_data_copy = raw_data.copy() # just so I don't mess up the real data

# %%
raw_data_copy['State County Site Code'] = raw_data_copy['State Code'].astype(str) + '-' + raw_data_copy['County Code'].astype(str) + '-' + raw_data_copy['Site Num'].astype(str)

# %%
raw_data_copy['SO2 AQI'] = raw_data_copy['SO2 AQI'].fillna(raw_data_copy.groupby(['State County Site Code', 'Date Local'])['SO2 AQI'].transform('mean'))
raw_data_copy['CO AQI'] = raw_data_copy['CO AQI'].fillna(raw_data_copy.groupby(['State County Site Code', 'Date Local'])['CO AQI'].transform('mean'))

# %%
raw_data_copy = raw_data_copy.dropna() #remove days with na values

# %%
raw_data_copy = raw_data_copy.drop(['Unnamed: 0', 'State Code', 'County Code', 'Site Num'], axis = 1)

# %%
raw_data_copy.head()
# Out:
#                                    Address    State    County     City  \
# 0  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 1  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 2  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 3  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 4  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
#
#    Date Local          NO2 Units   NO2 Mean  NO2 1st Max Value  \
# 0  2000-01-01  Parts per billion  19.041667               49.0
# 1  2000-01-01  Parts per billion  19.041667               49.0
# 2  2000-01-01  Parts per billion  19.041667               49.0
# 3  2000-01-01  Parts per billion  19.041667               49.0
# 4  2000-01-02  Parts per billion  22.958333               36.0
#
#    NO2 1st Max Hour  NO2 AQI  ...  SO2 Mean  SO2 1st Max Value  \
# 0                19       46  ...  3.000000                9.0
# 1                19       46  ...  3.000000                9.0
# 2                19       46  ...  2.975000                6.6
# 3                19       46  ...  2.975000                6.6
# 4                19       34  ...  1.958333                3.0
#
#    SO2 1st Max Hour  SO2 AQI           CO Units   CO Mean  CO 1st Max Value  \
# 0                21     13.0  Parts per million  1.145833               4.2
# 1                21     13.0  Parts per million  0.878947               2.2
# 2                23     13.0  Parts per million  1.145833               4.2
# 3                23     13.0  Parts per million  0.878947               2.2
# 4                22      4.0  Parts per million  0.850000               1.6
#
#    CO 1st Max Hour  CO AQI  State County Site Code
# 0               21    25.0               4-13-3002
# 1               23    25.0               4-13-3002
# 2               21    25.0               4-13-3002
# 3               23    25.0               4-13-3002
# 4               23    26.0               4-13-3002
#
# [5 rows x 26 columns]

# %%
new_data = raw_data_copy.groupby(['Address', 'Date Local'])[['NO2 Mean','NO2 AQI','O3 Mean','O3 AQI','SO2 Mean','SO2 AQI','CO Mean','CO AQI',]].transform('mean')
# this makes a new df with the named columns grouped by 'Address' and 'Date Local', and each replaced by its mean.
# you can use this alg to group data (say, by each 'City' and 'Date Local', and using their 'max') as required for your graph

# %%
print(new_data.shape)
print(raw_data_copy.shape)
# Out:
# (1746258, 8)
# (1746258, 26)

# %%
# choose appropriate columns to add to dataframe
new_data['Address'] = raw_data_copy['Address']
new_data['State'] = raw_data_copy['State']
new_data['County'] = raw_data_copy['County']
new_data['City'] = raw_data_copy['City']
new_data['Date Local'] = raw_data_copy['Date Local']
new_data['NO2 Units'] = raw_data_copy['NO2 Units']
new_data['O3 Units'] = raw_data_copy['O3 Units']
new_data['SO2 Units'] = raw_data_copy['SO2 Units']
new_data['CO Units'] = raw_data_copy['CO Units']
raw_data_copy = new_data

# %%
data_with_site = raw_data_copy.drop_duplicates()

# %%
data_with_site[(data_with_site['City'] == 'Washington') & (data_with_site['Date Local'] == '2000-05-10')]
# Out:
#         NO2 Mean  NO2 AQI   O3 Mean  O3 AQI  SO2 Mean  SO2 AQI   CO Mean  \
# 40282  18.666667     35.0  0.037792    47.0  7.309091     20.0  0.929356
#
#        CO AQI                                    Address  \
# 40282    11.0  420 34th Street N.E.,Washington, DC 20019
#
#                       State                County        City  Date Local  \
# 40282  District Of Columbia  District of Columbia  Washington  2000-05-10
#
#                NO2 Units           O3 Units          SO2 Units  \
# 40282  Parts per billion  Parts per million  Parts per billion
#
#                 CO Units
# 40282  Parts per million

# %%
new_data = data_with_site.groupby(['City', 'Date Local'])[['NO2 Mean','NO2 AQI','O3 Mean','O3 AQI','SO2 Mean','SO2 AQI','CO Mean','CO AQI']].transform('mean')
# grouped by city and date

# %%
print(new_data.shape)
print(data_with_site.shape)
# Out:
# (412650, 8)
# (412650, 17)

# %%
#new_data['Address'] = raw_data_copy['Address'] we don't need address
new_data['State'] = data_with_site['State']
new_data['County'] = data_with_site['County']
new_data['City'] = data_with_site['City']
new_data['Date Local'] = data_with_site['Date Local']
new_data['NO2 Units'] = data_with_site['NO2 Units']
new_data['O3 Units'] = data_with_site['O3 Units']
new_data['SO2 Units'] = data_with_site['SO2 Units']
new_data['CO Units'] = data_with_site['CO Units']
data_with_city = new_data

# %%
data_with_city = data_with_city.drop_duplicates()

# %%
new_data = data_with_city.groupby(['County', 'Date Local'])[['NO2 Mean','NO2 AQI','O3 Mean','O3 AQI','SO2 Mean','SO2 AQI','CO Mean','CO AQI']].transform('mean')
# grouped by county and date

# %%
print(new_data.shape)
print(data_with_city.shape)
# Out:
# (392161, 8)
# (392161, 16)

# %%
#new_data['Address'] = raw_data_copy['Address'] we don't need address
new_data['State'] = data_with_city['State']
new_data['County'] = data_with_city['County']
#new_data['City'] = raw_data_copy['City'] we dont' need city
new_data['Date Local'] = data_with_city['Date Local']
new_data['NO2 Units'] = data_with_city['NO2 Units']
new_data['O3 Units'] = data_with_city['O3 Units']
new_data['SO2 Units'] = data_with_city['SO2 Units']
new_data['CO Units'] = data_with_city['CO Units']
data_with_county = new_data

# %%
data_with_county = data_with_county.drop_duplicates()

# %%
new_data = data_with_county.groupby(['State', 'Date Local'])[['NO2 Mean','NO2 AQI','O3 Mean','O3 AQI','SO2 Mean','SO2 AQI','CO Mean','CO AQI']].transform('mean')
# grouped by state and date

# %%
#new_data['Address'] = raw_data_copy['Address'] we don't need address
new_data['State'] = data_with_county['State']
#new_data['County'] = raw_data_copy['County'] we dont' need county
#new_data['City'] = raw_data_copy['City'] we don't need city
new_data['Date Local'] = data_with_county['Date Local']
new_data['NO2 Units'] = data_with_county['NO2 Units']
new_data['O3 Units'] = data_with_county['O3 Units']
new_data['SO2 Units'] = data_with_county['SO2 Units']
new_data['CO Units'] = data_with_county['CO Units']
data_with_state = new_data

# %%
data_with_state = data_with_state.drop_duplicates()

# %%
raw_data = raw_data_copy

# %%
data_with_site.head()
# Out:
#      NO2 Mean  NO2 AQI   O3 Mean  O3 AQI  SO2 Mean  SO2 AQI   CO Mean  CO AQI  \
# 0   19.041667     46.0  0.022500    34.0  2.987500     13.0  1.012390    25.0
# 4   22.958333     34.0  0.013375    27.0  1.947917      4.0  0.958333    26.0
# 8   38.125000     48.0  0.007958    14.0  5.225000     16.0  1.845833    28.0
# 12  40.260870     72.0  0.014167    28.0  7.066667     23.0  1.910417    34.0
# 16  48.450000     58.0  0.006667    10.0  8.704166     21.0  2.660417    42.0
#
#                                     Address    State    County     City  \
# 0   1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 4   1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 8   1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 12  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
# 16  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa  Phoenix
#
#     Date Local          NO2 Units           O3 Units          SO2 Units  \
# 0   2000-01-01  Parts per billion  Parts per million  Parts per billion
# 4   2000-01-02  Parts per billion  Parts per million  Parts per billion
# 8   2000-01-03  Parts per billion  Parts per million  Parts per billion
# 12  2000-01-04  Parts per billion  Parts per million  Parts per billion
# 16  2000-01-05  Parts per billion  Parts per million  Parts per billion
#
#              CO Units
# 0   Parts per million
# 4   Parts per million
# 8   Parts per million
# 12  Parts per million
# 16  Parts per million

# %%
data_with_site['State'].nunique()
# Out:
# 47

# %%
# new DF for address above
roosevelt = data_with_site[data_with_site['Address'] == '1645 E ROOSEVELT ST-CENTRAL PHOENIX STN']
roosevelt['Date Local'] = pd.to_datetime(roosevelt['Date Local'])

#Plotting for address above with 100 data points, because there are many dates
fig, ax = plt.subplots(figsize = (12,6))
fig = sns.barplot(x = "Date Local", y = "NO2 Mean", data = roosevelt.head(100), ci = None, ax=ax)
x_dates = roosevelt['Date Local'].dt.strftime('%Y-%m-%d').sort_values()
ax.set_xticklabels(labels=x_dates, rotation=45, ha='right')
# Out:
# C:\Users\shubh\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# [Text(0, 0, '2000-01-01'),
#  Text(0, 0, '2000-01-02'),
#  Text(0, 0, '2000-01-03'),
#  Text(0, 0, '2000-01-04'),
#  Text(0, 0, '2000-01-05'),
#  Text(0, 0, '2000-01-06'),
#  Text(0, 0, '2000-01-07'),
#  Text(0, 0, '2000-01-08'),
#  Text(0, 0, '2000-01-09'),
#  Text(0, 0, '2000-01-10'),
#  Text(0, 0, '2000-01-11'),
#  Text(0, 0, '2000-01-12'),
#  Text(0, 0, '2000-01-13'),
#  Text(0, 0, '2000-01-14'),
#  Text(0, 0, '2000-01-15'),
#  Text(0, 0, '2000-01-16'),
#  Text(0, 0, '2000-01-17'),
#  Text(0, 0, '2000-01-18'),
#  Text(0, 0, '2000-01-19'),
#  Text(0, 0, '2000-01-20'),
#  Text(0, 0, '2000-01-21'),
#  Text(0, 0, '2000-01-22'),
#  Text(0, 0, '2000-01-23'),
#  Text(0, 0, '2000-01-24'),
#  Text(0, 0, '2000-01-25'),
#  Text(0, 0, '2000-01-26'),
#  Text(0, 0, '2000-01-27'),
#  Text(0, 0, '2000-01-28'),
#  Text(0, 0, '2000-01-29'),
#  Text(0, 0, '2000-01-30'),
#  Text(0, 0, '2000-01-31'),
#  Text(0, 0, '2000-02-01'),
#  Text(0, 0, '2000-02-02'),
#  Text(0, 0, '2000-02-03'),
#  Text(0, 0, '2000-02-04'),
#  Text(0, 0, '2000-02-05'),
#  Text(0, 0, '2000-02-06'),
#  Text(0, 0, '2000-02-07'),
#  Text(0, 0, '2000-02-08'),
#  Text(0, 0, '2000-02-09'),
#  Text(0, 0, '2000-02-10'),
#  Text(0, 0, '2000-02-11'),
#  Text(0, 0, '2000-02-12'),
#  Text(0, 0, '2000-02-13'),
#  Text(0, 0, '2000-02-14'),
#  Text(0, 0, '2000-02-15'),
#  Text(0, 0, '2000-02-16'),
#  Text(0, 0, '2000-02-17'),
#  Text(0, 0, '2000-02-18'),
#  Text(0, 0, '2000-02-19'),
#  Text(0, 0, '2000-02-20'),
#  Text(0, 0, '2000-02-21'),
#  Text(0, 0, '2000-02-22'),
#  Text(0, 0, '2000-02-23'),
#  Text(0, 0, '2000-02-24'),
#  Text(0, 0, '2000-02-25'),
#  Text(0, 0, '2000-02-26'),
#  Text(0, 0, '2000-02-27'),
#  Text(0, 0, '2000-02-28'),
#  Text(0, 0, '2000-02-29'),
#  Text(0, 0, '2000-03-01'),
#  Text(0, 0, '2000-03-02'),
#  Text(0, 0, '2000-03-03'),
#  Text(0, 0, '2000-03-04'),
#  Text(0, 0, '2000-03-05'),
#  Text(0, 0, '2000-03-06'),
#  Text(0, 0, '2000-03-07'),
#  Text(0, 0, '2000-03-08'),
#  Text(0, 0, '2000-03-09'),
#  Text(0, 0, '2000-03-10'),
#  Text(0, 0, '2000-03-11'),
#  Text(0, 0, '2000-03-12'),
#  Text(0, 0, '2000-03-13'),
#  Text(0, 0, '2000-03-14'),
#  Text(0, 0, '2000-03-15'),
#  Text(0, 0, '2000-03-16'),
#  Text(0, 0, '2000-03-17'),
#  Text(0, 0, '2000-03-18'),
#  Text(0, 0, '2000-03-19'),
#  Text(0, 0, '2000-03-20'),
#  Text(0, 0, '2000-03-21'),
#  Text(0, 0, '2000-03-22'),
#  Text(0, 0, '2000-03-23'),
#  Text(0, 0, '2000-03-24'),
#  Text(0, 0, '2000-03-25'),
#  Text(0, 0, '2000-03-26'),
#  Text(0, 0, '2000-03-27'),
#  Text(0, 0, '2000-03-28'),
#  Text(0, 0, '2000-03-29'),
#  Text(0, 0, '2000-03-30'),
#  Text(0, 0, '2000-03-31'),
#  Text(0, 0, '2000-04-01'),
#  Text(0, 0, '2000-04-02'),
#  Text(0, 0, '2000-04-03'),
#  Text(0, 0, '2000-04-04'),
#  Text(0, 0, '2000-04-05'),
#  Text(0, 0, '2000-04-11'),
#  Text(0, 0, '2000-04-12'),
#  Text(0, 0, '2000-04-13'),
#  Text(0, 0, '2000-04-14')]

# %%
month_for_site = data_with_site['Date Local'].str[:7] # series of YYYY-MM
data_with_site_month = data_with_site  # make a copy of df with sites and dates
data_with_site_month = data_with_site_month.drop('Date Local', axis = 1) # drop the date
data_with_site_month['YYYY-MM Date'] = month_for_site # add new formatted date
data_with_site_month
# Out:
#           NO2 Mean  NO2 AQI   O3 Mean  O3 AQI   SO2 Mean  SO2 AQI   CO Mean  \
# 0        19.041667     46.0  0.022500    34.0   2.987500     13.0  1.012390
# 4        22.958333     34.0  0.013375    27.0   1.947917      4.0  0.958333
# 8        38.125000     48.0  0.007958    14.0   5.225000     16.0  1.845833
# 12       40.260870     72.0  0.014167    28.0   7.066667     23.0  1.910417
# 16       48.450000     58.0  0.006667    10.0   8.704166     21.0  2.660417
# 20       39.950000     71.0  0.011750    21.0   6.914286     24.0  2.141123
# 24       29.625000     41.0  0.011625    20.0   8.652083     30.0  2.095833
# 28       29.666667     39.0  0.009750    17.0   8.231250     26.0  2.664583
# 32       25.083333     35.0  0.010792    19.0   6.487500     19.0  1.702083
# 36       37.666667     68.0  0.008458    13.0   9.941667     30.0  2.260417
# 40       50.500000     80.0  0.008417    14.0  11.612500     34.0  2.568750
# 44       49.125000     80.0  0.008208    12.0  10.895834     37.0  2.306250
# 48       73.285714    104.0  0.006167     8.0  11.359524     30.0  3.047349
# 52       66.541667    105.0  0.008708    15.0  11.606250     41.0  3.293750
# 56       53.166667     86.0  0.010625    19.0   9.566667     31.0  2.464583
# 60       45.750000     71.0  0.010750    19.0   6.447916     19.0  1.762500
# 64       59.250000    101.0  0.008375    13.0   8.475000     27.0  2.110416
# 68       66.791667    101.0  0.006333     8.0  12.145834     33.0  2.941667
# 72       59.041667     86.0  0.006958    11.0  10.152083     31.0  2.591667
# 76       48.357143     63.0  0.008500    14.0   9.445652     24.0  2.299243
# 80       54.500000     58.0  0.008542    12.0   7.929167     24.0  1.966667
# 84       38.083333     62.0  0.010583    17.0   6.862500     20.0  1.893750
# 88       37.958333     64.0  0.016292    31.0   6.777083     20.0  1.920834
# 92       53.333333     76.0  0.011417    19.0   9.066667     26.0  1.985417
# 96       42.583333     56.0  0.009917    17.0   7.816667     16.0  1.391667
# 100      27.217391     40.0  0.017750    30.0   3.331818     10.0  0.813769
# 104      33.375000     48.0  0.014000    24.0   4.082105     16.0  1.035417
# 108      36.875000     51.0  0.013000    23.0   4.251190     20.0  1.445833
# 112      39.625000     64.0  0.017083    31.0   6.312281     24.0  1.866667
# 116      35.208333     54.0  0.016750    30.0   2.566667     14.0  1.364584
# ...            ...      ...       ...     ...        ...      ...       ...
# 1746541   1.195652      3.0  0.041750    43.0  -0.095130      0.0  0.102568
# 1746545   0.870833      1.0  0.043375    44.0  -0.116666      0.0  0.095209
# 1746549   3.517391     10.0  0.043958    48.0  -0.046429      0.0  0.141470
# 40       Parts per billion  Parts per million      2000-01
# 44       Parts per billion  Parts per million      2000-01
# 48       Parts per billion  Parts per million      2000-01
# 52       Parts per billion  Parts per million      2000-01
# 56       Parts per billion  Parts per million      2000-01
# 60       Parts per billion  Parts per million      2000-01
# 64       Parts per billion  Parts per million      2000-01
# 68       Parts per billion  Parts per million      2000-01
# 72       Parts per billion  Parts per million      2000-01
# 76       Parts per billion  Parts per million      2000-01
# 80       Parts per billion  Parts per million      2000-01
# 84       Parts per billion  Parts per million      2000-01
# 88       Parts per billion  Parts per million      2000-01
# 92       Parts per billion  Parts per million      2000-01
# 96       Parts per billion  Parts per million      2000-01
# 100      Parts per billion  Parts per million      2000-01
# 104      Parts per billion  Parts per million      2000-01
# 108      Parts per billion  Parts per million      2000-01
# 112      Parts per billion  Parts per million      2000-01
# 116      Parts per billion  Parts per million      2000-01
# ...                    ...                ...          ...
# 1746541  Parts per billion  Parts per million      2016-03
# 1746545  Parts per billion  Parts per million      2016-03
# 1746549  Parts per billion  Parts per million      2016-03
# 1746553  Parts per billion  Parts per million      2016-03
# 1746557  Parts per billion  Parts per million      2016-03
# 1746561  Parts per billion  Parts per million      2016-03
# 1746565  Parts per billion  Parts per million      2016-03
# 1746569  Parts per billion  Parts per million      2016-03
# 1746573  Parts per billion  Parts per million      2016-03
# 1746577  Parts per billion  Parts per million      2016-03
# 1746581  Parts per billion  Parts per million      2016-03
# 1746585  Parts per billion  Parts per million      2016-03
# 1746589  Parts per billion  Parts per million      2016-03
# 1746593  Parts per billion  Parts per million      2016-03
# 1746597  Parts per billion  Parts per million      2016-03
# 1746601  Parts per billion  Parts per million      2016-03
# 1746605  Parts per billion  Parts per million      2016-03
# 1746609  Parts per billion  Parts per million      2016-03
# 1746613  Parts per billion  Parts per million      2016-03
# 1746617  Parts per billion  Parts per million      2016-03
# 1746621  Parts per billion  Parts per million      2016-03
# 1746625  Parts per billion  Parts per million      2016-03
# 1746629  Parts per billion  Parts per million      2016-03
# 1746633  Parts per billion  Parts per million      2016-03
# 1746637  Parts per billion  Parts per million      2016-03
# 1746641  Parts per billion  Parts per million      2016-03
# 1746645  Parts per billion  Parts per million      2016-03
# 1746649  Parts per billion  Parts per million      2016-03
# 1746653  Parts per billion  Parts per million      2016-03
# 1746657  Parts per billion  Parts per million      2016-03
#
# [412650 rows x 17 columns]

# %%
new_data = data_with_site_month.groupby(['Address', 'YYYY-MM Date'])[['NO2 Mean','NO2 AQI','O3 Mean','O3 AQI','SO2 Mean','SO2 AQI','CO Mean','CO AQI']].transform('mean')
# group by address and YYYY-MM Date

# %%
new_data['Address'] = data_with_site_month['Address']
new_data['State'] = data_with_site_month['State']
new_data['County'] = data_with_site_month['County']
new_data['City'] = data_with_site_month['City']
new_data['YYYY-MM Date'] = data_with_site_month['YYYY-MM Date']
new_data['NO2 Units'] = data_with_site_month['NO2 Units']
new_data['O3 Units'] = data_with_site_month['O3 Units']
new_data['SO2 Units'] = data_with_site_month['SO2 Units']
new_data['CO Units'] = data_with_site_month['CO Units']
data_with_site_month_grouped = new_data

# %%
data_with_site_month_grouped = data_with_site_month_grouped.drop_duplicates()

# %%
data_with_site_month_grouped.head()
# Out:
#       NO2 Mean    NO2 AQI   O3 Mean     O3 AQI  SO2 Mean    SO2 AQI   CO Mean  \
# 0    43.203521  64.903226  0.011238  19.193548  7.436753  23.096774  1.993244
# 124  36.495144  57.827586  0.016516  29.034483  3.874216  17.896552  1.268334
# 240  32.916190  56.225806  0.023027  39.903226  0.560594   2.290323  0.918476
# 364  28.736916  57.160000  0.028745  49.840000  1.507525   8.760000  0.918006
# 468   2.872158   5.888889  0.031542  56.703704  1.585462   8.555556  0.775860
#
#         CO AQI                                  Address    State    County  \
# 0    40.096774  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 124  27.620690  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 240  18.967742  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 364  18.800000  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
# 468  15.592593  1645 E ROOSEVELT ST-CENTRAL PHOENIX STN  Arizona  Maricopa
#
#         City YYYY-MM Date          NO2 Units           O3 Units  \
# 0    Phoenix      2000-01  Parts per billion  Parts per million
# 124  Phoenix      2000-02  Parts per billion  Parts per million
# 240  Phoenix      2000-03  Parts per billion  Parts per million
# 364  Phoenix      2000-04  Parts per billion  Parts per million
# 468  Phoenix      2000-05  Parts per billion  Parts per million
#
#              SO2 Units           CO Units
# 0    Parts per billion  Parts per million
# 124  Parts per billion  Parts per million
# 240  Parts per billion  Parts per million
# 364  Parts per billion  Parts per million
# 468  Parts per billion  Parts per million

# %%
#a new DF for address
roosevelt_month = data_with_site_month_grouped[data_with_site_month_grouped['Address'] == '1645 E ROOSEVELT ST-CENTRAL PHOENIX STN']
roosevelt_month['YYYY-MM Date'] = pd.to_datetime(roosevelt_month['YYYY-MM Date']) #this makes date YYYY-MM-DD

#plotting 100 data points
fig_m, ax_m = plt.subplots(figsize = (20,6))
fig_m = sns.barplot(x = "YYYY-MM Date", y = "NO2 Mean", data = roosevelt_month.head(100), ci = None, ax=ax_m)
x_dates_m = roosevelt_month['YYYY-MM Date'].dt.strftime('%Y-%m').sort_values()
ax_m.set_xticklabels(labels=x_dates_m, rotation=45, ha='right')
# Out:
# C:\Users\shubh\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# [Text(0, 0, '2000-01'),
#  Text(0, 0, '2000-02'),
#  Text(0, 0, '2000-03'),
#  Text(0, 0, '2000-04'),
#  Text(0, 0, '2000-05'),
#  Text(0, 0, '2000-06'),
#  Text(0, 0, '2000-07'),
#  Text(0, 0, '2000-08'),
#  Text(0, 0, '2000-09'),
#  Text(0, 0, '2000-10'),
#  Text(0, 0, '2000-11'),
#  Text(0, 0, '2000-12'),
#  Text(0, 0, '2001-01'),
#  Text(0, 0, '2001-02'),
#  Text(0, 0, '2001-03'),
#  Text(0, 0, '2001-04'),
#  Text(0, 0, '2001-05'),
#  Text(0, 0, '2001-06'),
#  Text(0, 0, '2001-07'),
#  Text(0, 0, '2001-08'),
#  Text(0, 0, '2001-09'),
#  Text(0, 0, '2001-10'),
#  Text(0, 0, '2001-11'),
#  Text(0, 0, '2001-12'),
#  Text(0, 0, '2002-01'),
#  Text(0, 0, '2002-02'),
#  Text(0, 0, '2002-03'),
#  Text(0, 0, '2002-04'),
#  Text(0, 0, '2002-05'),
#  Text(0, 0, '2002-06'),
#  Text(0, 0, '2002-07'),
#  Text(0, 0, '2002-08'),
#  Text(0, 0, '2002-09'),
#  Text(0, 0, '2002-10'),
#  Text(0, 0, '2002-11'),
#  Text(0, 0, '2002-12'),
#  Text(0, 0, '2003-01'),
#  Text(0, 0, '2003-02'),
#  Text(0, 0, '2003-03'),
#  Text(0, 0, '2003-04'),
#  Text(0, 0, '2003-05'),
#  Text(0, 0, '2003-06'),
#  Text(0, 0, '2003-07'),
#  Text(0, 0, '2003-10'),
#  Text(0, 0, '2003-11'),
#  Text(0, 0, '2003-12'),
#  Text(0, 0, '2004-01'),
#  Text(0, 0, '2004-02'),
#  Text(0, 0, '2004-03'),
#  Text(0, 0, '2004-04'),
#  Text(0, 0, '2004-05'),
#  Text(0, 0, '2004-06'),
#  Text(0, 0, '2004-07'),
#  Text(0, 0, '2004-08'),
#  Text(0, 0, '2004-09'),
#  Text(0, 0, '2004-10'),
#  Text(0, 0, '2004-11'),
#  Text(0, 0, '2004-12'),
#  Text(0, 0, '2005-01'),
#  Text(0, 0, '2005-02'),
#  Text(0, 0, '2005-03'),
#  Text(0, 0, '2005-04'),
#  Text(0, 0, '2005-05'),
#  Text(0, 0, '2005-06'),
#  Text(0, 0, '2005-07'),
#  Text(0, 0, '2005-08'),
#  Text(0, 0, '2005-09'),
#  Text(0, 0, '2005-10'),
#  Text(0, 0, '2005-11'),
#  Text(0, 0, '2005-12'),
#  Text(0, 0, '2006-01'),
#  Text(0, 0, '2006-02'),
#  Text(0, 0, '2006-03'),
#  Text(0, 0, '2006-04'),
#  Text(0, 0, '2006-05'),
#  Text(0, 0, '2006-06'),
#  Text(0, 0, '2006-07'),
#  Text(0, 0, '2006-08'),
#  Text(0, 0, '2006-09'),
#  Text(0, 0, '2006-10'),
#  Text(0, 0, '2006-11'),
#  Text(0, 0, '2006-12'),
#  Text(0, 0, '2007-01'),
#  Text(0, 0, '2007-02'),
#  Text(0, 0, '2007-03'),
#  Text(0, 0, '2007-04'),
#  Text(0, 0, '2007-05'),
#  Text(0, 0, '2007-06'),
#  Text(0, 0, '2007-07'),
#  Text(0, 0, '2007-08'),
#  Text(0, 0, '2007-09'),
#  Text(0, 0, '2007-10'),
#  Text(0, 0, '2007-11'),
#  Text(0, 0, '2007-12'),
#  Text(0, 0, '2008-01'),
#  Text(0, 0, '2008-02'),
#  Text(0, 0, '2008-03'),
#  Text(0, 0, '2008-04'),
#  Text(0, 0, '2008-05'),
#  Text(0, 0, '2008-06')]

# %%
data_with_city.head()
# Out:
#      NO2 Mean  NO2 AQI   O3 Mean  O3 AQI  SO2 Mean  SO2 AQI   CO Mean  CO AQI  \
# 0   19.041667     46.0  0.022500    34.0  2.987500     13.0  1.012390    25.0
# 4   22.958333     34.0  0.013375    27.0  1.947917      4.0  0.958333    26.0
# 8   38.125000     48.0  0.007958    14.0  5.225000     16.0  1.845833    28.0
# 12  40.260870     72.0  0.014167    28.0  7.066667     23.0  1.910417    34.0
# 16  48.450000     58.0  0.006667    10.0  8.704166     21.0  2.660417    42.0
#
#       State    County     City  Date Local          NO2 Units  \
# 0   Arizona  Maricopa  Phoenix  2000-01-01  Parts per billion
# 4   Arizona  Maricopa  Phoenix  2000-01-02  Parts per billion
# 8   Arizona  Maricopa  Phoenix  2000-01-03  Parts per billion
# 12  Arizona  Maricopa  Phoenix  2000-01-04  Parts per billion
# 16  Arizona  Maricopa  Phoenix  2000-01-05  Parts per billion
#
#              O3 Units          SO2 Units           CO Units
# 0   Parts per million  Parts per billion  Parts per million
# 4   Parts per million  Parts per billion  Parts per million
# 8   Parts per million  Parts per billion  Parts per million
# 12  Parts per million  Parts per billion  Parts per million
# 16  Parts per million  Parts per billion  Parts per million

# %%
# plotting for phoenix
phoenix = data_with_city[data_with_city['City'] == 'Phoenix']
phoenix['Date Local'] = pd.to_datetime(phoenix['Date Local'])

#Plotting for city above with 100 data points, because there are many dates
fig, ax = plt.subplots(figsize = (12,6))
fig = sns.scatterplot(x = "Date Local", y = "NO2 Mean", data = phoenix.head(100), ax=ax)
x_dates = phoenix['Date Local'].dt.strftime('%Y-%m-%d').sort_values()
ax.set(xlim = ('1999-12-25', '2000-04-14'))
# Out:
# C:\Users\shubh\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# [(730113.0, 730224.0)]

# %%
month_for_city = data_with_city['Date Local'].str[:7] # series of YYYY-MM
data_with_city_month = data_with_city # make a copy of df with cities and dates
data_with_city_month = data_with_city_month.drop('Date Local', axis = 1) # drop the date column
data_with_city_month['YYYY-MM Date'] = month_for_city # add new formatted YYYY-MM Date
data_with_city_month
# Out:
#           NO2 Mean     NO2 AQI   O3 Mean     O3 AQI   SO2 Mean    SO2 AQI  \
# 0        19.041667   46.000000  0.022500  34.000000   2.987500  13.000000
# 4        22.958333   34.000000  0.013375  27.000000   1.947917   4.000000
# 8        38.125000   48.000000  0.007958  14.000000   5.225000  16.000000
# 12       40.260870   72.000000  0.014167  28.000000   7.066667  23.000000
# 16       48.450000   58.000000  0.006667  10.000000   8.704166  21.000000
# 20       39.950000   71.000000  0.011750  21.000000   6.914286  24.000000
# 24       29.625000   41.000000  0.011625  20.000000   8.652083  30.000000
# 28       29.666667   39.000000  0.009750  17.000000   8.231250  26.000000
# 32       25.083333   35.000000  0.010792  19.000000   6.487500  19.000000
# 36       37.666667   68.000000  0.008458  13.000000   9.941667  30.000000
# 40       50.500000   80.000000  0.008417  14.000000  11.612500  34.000000
# 44       49.125000   80.000000  0.008208  12.000000  10.895834  37.000000
# 48       73.285714  104.000000  0.006167   8.000000  11.359524  30.000000
# 52       66.541667  105.000000  0.008708  15.000000  11.606250  41.000000
# 56       53.166667   86.000000  0.010625  19.000000   9.566667  31.000000
# 60       45.750000   71.000000  0.010750  19.000000   6.447916  19.000000
# 64       59.250000  101.000000  0.008375  13.000000   8.475000  27.000000
# 68       66.791667  101.000000  0.006333   8.000000  12.145834  33.000000
# 72       59.041667   86.000000  0.006958  11.000000  10.152083  31.000000
# 76       48.357143   63.000000  0.008500  14.000000   9.445652  24.000000
# 80       54.500000   58.000000  0.008542  12.000000   7.929167  24.000000
# 84       38.083333   62.000000  0.010583  17.000000   6.862500  20.000000
# 88       37.958333   64.000000  0.016292  31.000000   6.777083  20.000000
# 92       53.333333   76.000000  0.011417  19.000000   9.066667  26.000000
# 96       42.583333   56.000000  0.009917  17.000000   7.816667  16.000000
# 100      27.217391   40.000000  0.017750  30.000000   3.331818  10.000000
# 104      33.375000   48.000000  0.014000  24.000000   4.082105  16.000000
# 1746657  0.163125   2.000000  Wyoming   Laramie  Not in a city
#
#                  NO2 Units           O3 Units          SO2 Units  \
# 0        Parts per billion  Parts per million  Parts per billion
# 4        Parts per billion  Parts per million  Parts per billion
# 8        Parts per billion  Parts per million  Parts per billion
# 12       Parts per billion  Parts per million  Parts per billion
# 16       Parts per billion  Parts per million  Parts per billion
# 20       Parts per billion  Parts per million  Parts per billion
# 24       Parts per billion  Parts per million  Parts per billion
# 28       Parts per billion  Parts per million  Parts per billion
# 32       Parts per billion  Parts per million  Parts per billion
# 36       Parts per billion  Parts per million  Parts per billion
# 40       Parts per billion  Parts per million  Parts per billion
# 44       Parts per billion  Parts per million  Parts per billion
# 48       Parts per billion  Parts per million  Parts per billion
# 52       Parts per billion  Parts per million  Parts per billion
# 56       Parts per billion  Parts per million  Parts per billion
# 60       Parts per billion  Parts per million  Parts per billion
# 64       Parts per billion  Parts per million  Parts per billion
# 68       Parts per billion  Parts per million  Parts per billion
# 72       Parts per billion  Parts per million  Parts per billion
# 76       Parts per billion  Parts per million  Parts per billion
# 80       Parts per billion  Parts per million  Parts per billion
# 84       Parts per billion  Parts per million  Parts per billion
# 88       Parts per billion  Parts per million  Parts per billion
# 92       Parts per billion  Parts per million  Parts per billion
# 96       Parts per billion  Parts per million  Parts per billion
# 100      Parts per billion  Parts per million  Parts per billion
# 104      Parts per billion  Parts per million  Parts per billion
# 108      Parts per billion  Parts per million  Parts per billion
# 112      Parts per billion  Parts per million  Parts per billion
# 116      Parts per billion  Parts per million  Parts per billion
# ...                    ...                ...                ...
# 1746541  Parts per billion  Parts per million  Parts per billion
# 1746545  Parts per billion  Parts per million  Parts per billion
# 1746549  Parts per billion  Parts per million  Parts per billion
# 1746553  Parts per billion  Parts per million  Parts per billion
# 1746557  Parts per billion  Parts per million  Parts per billion
# 1746561  Parts per billion  Parts per million  Parts per billion
# 1746565  Parts per billion  Parts per million  Parts per billion
# 1746569  Parts per billion  Parts per million  Parts per billion
# 1746573  Parts per billion  Parts per million  Parts per billion
# 1746577  Parts per billion  Parts per million  Parts per billion
# 1746581  Parts per billion  Parts per million  Parts per billion
# 1746585  Parts per billion  Parts per million  Parts per billion
# 1746589  Parts per billion  Parts per million  Parts per billion
# 1746593  Parts per billion  Parts per million  Parts per billion
# 1746597  Parts per billion  Parts per million  Parts per billion
# 1746601  Parts per billion  Parts per million  Parts per billion
# 1746605  Parts per billion  Parts per million  Parts per billion
# 1746609  Parts per billion  Parts per million  Parts per billion
# 1746613  Parts per billion  Parts per million  Parts per billion
# 1746617  Parts per billion  Parts per million  Parts per billion
# 1746621  Parts per billion  Parts per million  Parts per billion
# 1746625  Parts per billion  Parts per million  Parts per billion
# 1746629  Parts per billion  Parts per million  Parts per billion
# 1746633  Parts per billion  Parts per million  Parts per billion
# 1746637  Parts per billion  Parts per million  Parts per billion
# 1746641  Parts per billion  Parts per million  Parts per billion
# 1746645  Parts per billion  Parts per million  Parts per billion
# 1746649  Parts per billion  Parts per million  Parts per billion
# 1746653  Parts per billion  Parts per million  Parts per billion
# 1746657  Parts per billion  Parts per million  Parts per billion
#
#                   CO Units YYYY-MM Date
# 0        Parts per million      2000-01
# 4        Parts per million      2000-01
# 8        Parts per million      2000-01
# 12       Parts per million      2000-01
# 16       Parts per million      2000-01
# 20       Parts per million      2000-01
# 24       Parts per million      2000-01
# 28       Parts per million      2000-01
# 32       Parts per million      2000-01
# 36       Parts per million      2000-01
# 40       Parts per million      2000-01
# 44       Parts per million      2000-01
# 48       Parts per million      2000-01
# 52       Parts per million      2000-01
# 56       Parts per million      2000-01
# 60       Parts per million      2000-01
# 64       Parts per million      2000-01
# 68       Parts per million      2000-01
# 72       Parts per million      2000-01
# 76       Parts per million      2000-01
# 80       Parts per million      2000-01
# 84       Parts per million      2000-01
# 88       Parts per million      2000-01
# 92       Parts per million      2000-01
# 96       Parts per million      2000-01
# 100      Parts per million      2000-01
# 104      Parts per million      2000-01
# 108      Parts per million      2000-01
# 112      Parts per million      2000-01
# 116      Parts per million      2000-01
# ...                    ...          ...
# 1746541  Parts per million      2016-03
# 1746545  Parts per million      2016-03
# 1746549  Parts per million      2016-03
# 1746553  Parts per million      2016-03
# 1746557  Parts per million      2016-03
# 1746561  Parts per million      2016-03
# 1746565  Parts per million      2016-03
# 1746569  Parts per million      2016-03
# 1746573  Parts per million      2016-03
# 1746577  Parts per million      2016-03
# 1746581  Parts per million      2016-03
# 1746585  Parts per million      2016-03
# 1746589  Parts per million      2016-03
# 1746593  Parts per million      2016-03
# 1746597  Parts per million      2016-03
# 1746601  Parts per million      2016-03
# 1746605  Parts per million      2016-03
# 1746609  Parts per million      2016-03
# 1746613  Parts per million      2016-03
# 1746617  Parts per million      2016-03
# 1746621  Parts per million      2016-03
# 1746625  Parts per million      2016-03
# 1746629  Parts per million      2016-03
# 1746633  Parts per million      2016-03
# 1746637  Parts per million      2016-03
# 1746641  Parts per million      2016-03
# 1746645  Parts per million      2016-03
# 1746649  Parts per million      2016-03
# 1746653  Parts per million      2016-03
# 1746657  Parts per million      2016-03
#
# [392161 rows x 16 columns]

# %%
new_data = data_with_city_month.groupby(['City', 'YYYY-MM Date'])[['NO2 Mean','NO2 AQI','O3 Mean','O3 AQI','SO2 Mean','SO2 AQI','CO Mean','CO AQI']].transform('mean')
# grouped by city and YYYY-MM Date

# %%
print(new_data.shape)
print(data_with_city_month.shape)
# Out:
# (392161, 16)
# (392161, 16)

# %%
#new_data['Address'] = raw_data_copy['Address'] we don't need address
new_data['State'] = data_with_city_month['State']
new_data['County'] = data_with_city_month['County']
new_data['City'] = data_with_city_month['City']
new_data['YYYY-MM Date'] = data_with_city_month['YYYY-MM Date']
new_data['NO2 Units'] = data_with_city_month['NO2 Units']
new_data['O3 Units'] = data_with_city_month['O3 Units']
new_data['SO2 Units'] = data_with_city_month['SO2 Units']
new_data['CO Units'] = data_with_city_month['CO Units']
data_with_city_month_grouped = new_data

# %%
data_with_city_month_grouped = data_with_city_month_grouped.drop_duplicates()

# %%
data_with_city_month_grouped.head()
# Out:
#       NO2 Mean    NO2 AQI   O3 Mean     O3 AQI  SO2 Mean    SO2 AQI   CO Mean  \
# 0    43.203521  64.903226  0.011238  19.193548  7.436753  23.096774  1.993244
# 124  36.495144  57.827586  0.016516  29.034483  3.874216  17.896552  1.268334
# 240  32.916190  56.225806  0.023027  39.903226  0.560594   2.290323  0.918476
# 364  28.736916  57.160000  0.028745  49.840000  1.507525   8.760000  0.918006
# 468   2.872158   5.888889  0.031542  56.703704  1.585462   8.555556  0.775860
#
#         CO AQI    State    County     City YYYY-MM Date          NO2 Units  \
# 0    40.096774  Arizona  Maricopa  Phoenix      2000-01  Parts per billion
# 124  27.620690  Arizona  Maricopa  Phoenix      2000-02  Parts per billion
# 240  18.967742  Arizona  Maricopa  Phoenix      2000-03  Parts per billion
# 364  18.800000  Arizona  Maricopa  Phoenix      2000-04  Parts per billion
# 468  15.592593  Arizona  Maricopa  Phoenix      2000-05  Parts per billion
#
#               O3 Units          SO2 Units           CO Units
# 0    Parts per million  Parts per billion  Parts per million
# 124  Parts per million  Parts per billion  Parts per million
# 240  Parts per million  Parts per billion  Parts per million
# 364  Parts per million  Parts per billion  Parts per million
# 468  Parts per million  Parts per billion  Parts per million

# %%
# plotting for phoenix
phoenix_month = data_with_city_month_grouped[data_with_city_month_grouped['City'] == 'Los Angeles']
phoenix_month['YYYY-MM Date'] = pd.to_datetime(phoenix_month['YYYY-MM Date']) #this makes date YYYY-MM-DD

#Plotting for city above with 100 data points, because there are many dates
fig, ax = plt.subplots(figsize = (12,6))
fig = sns.scatterplot(x = "YYYY-MM Date", y = "CO Mean", data = phoenix_month, ax=ax)
x_dates = phoenix_month['YYYY-MM Date'].dt.strftime('%Y-%m').sort_values()
ax.set(xlim = ('2000-12', '2015-12'))#, ylim = (0, 1))
# Out:
# C:\Users\shubh\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# [(730455.0, 735933.0)]

# %%
data_with_county.head()
# Out:
#      NO2 Mean  NO2 AQI   O3 Mean  O3 AQI  SO2 Mean  SO2 AQI   CO Mean  CO AQI  \
# 0   33.125000     73.5  0.021125    33.5  2.365625      8.0  0.858333    20.0
# 4   25.520833     56.0  0.013813    25.0  1.658333      3.5  0.736458    20.5
# 8   50.419643     81.0  0.012125    20.5  3.120833     11.0  1.523390    23.5
# 12  48.255435     93.0  0.018750    33.5  3.905208     15.0  1.303125    28.0
# 16  76.975000     85.5  0.008667    14.5  5.175000     13.5  2.120833    34.0
#
#       State    County  Date Local          NO2 Units           O3 Units  \
# 0   Arizona  Maricopa  2000-01-01  Parts per billion  Parts per million
# 4   Arizona  Maricopa  2000-01-02  Parts per billion  Parts per million
# 8   Arizona  Maricopa  2000-01-03  Parts per billion  Parts per million
# 12  Arizona  Maricopa  2000-01-04  Parts per billion  Parts per million
# 16  Arizona  Maricopa  2000-01-05  Parts per billion  Parts per million
#
#             SO2 Units           CO Units
# 0   Parts per billion  Parts per million
# 4   Parts per billion  Parts per million
# 8   Parts per billion  Parts per million
# 12  Parts per billion  Parts per million
# 16  Parts per billion  Parts per million

# %%
# new DF for address above
maricopa = data_with_county[data_with_county['County'] == 'Maricopa']
maricopa['Date Local'] = pd.to_datetime(maricopa['Date Local'])

#Plotting for county above with 100 data points, because there are many dates
fig, ax = plt.subplots(figsize = (12,6))
fig = sns.lineplot(x = "Date Local", y = "NO2 Mean", data = maricopa.head(100), ci = None, ax=ax)
x_dates = maricopa['Date Local'].dt.strftime('%Y-%m-%d').sort_values()
# Out:
# C:\Users\shubh\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
# 104      0.931250  17.000000  Arizona  Maricopa  Parts per billion
# 108      1.262500  21.000000  Arizona  Maricopa  Parts per billion
# 112      1.515625  28.500000  Arizona  Maricopa  Parts per billion
# 116      1.103125  33.000000  Arizona  Maricopa  Parts per billion
# ...           ...        ...      ...       ...                ...
# 1746541  0.223658   3.142857  Wyoming   Laramie  Parts per billion
# 1746545  0.178959   2.000000  Wyoming   Laramie  Parts per billion
# 1746549  0.217293   3.142857  Wyoming   Laramie  Parts per billion
# 1746553  0.201257   2.857143  Wyoming   Laramie  Parts per billion
# 1746557  0.257863   3.428571  Wyoming   Laramie  Parts per billion
# 1746561  0.219463   3.285714  Wyoming   Laramie  Parts per billion
# 1746565  0.218133   3.571429  Wyoming   Laramie  Parts per billion
# 1746569  0.200409   2.857143  Wyoming   Laramie  Parts per billion
# 1746573  0.183526   2.571429  Wyoming   Laramie  Parts per billion
# 1746577  0.168503   2.571429  Wyoming   Laramie  Parts per billion
# 1746581  0.181339   2.571429  Wyoming   Laramie  Parts per billion
# 1746585  0.164554   2.142857  Wyoming   Laramie  Parts per billion
# 1746589  0.185355   2.857143  Wyoming   Laramie  Parts per billion
# 1746593  0.152948   2.285714  Wyoming   Laramie  Parts per billion
# 1746597  0.149966   2.000000  Wyoming   Laramie  Parts per billion
# 1746601  0.183227   2.571429  Wyoming   Laramie  Parts per billion
# 1746605  0.177290   2.428571  Wyoming   Laramie  Parts per billion
# 1746609  0.162527   1.714286  Wyoming   Laramie  Parts per billion
# 1746613  0.151549   1.714286  Wyoming   Laramie  Parts per billion
# 1746617  0.193081   2.333333  Wyoming   Laramie  Parts per billion
# 1746621  0.181140   2.285714  Wyoming   Laramie  Parts per billion
# 1746625  0.178022   2.714286  Wyoming   Laramie  Parts per billion
# 1746629  0.200910   2.714286  Wyoming   Laramie  Parts per billion
# 1746633  0.184160   2.714286  Wyoming   Laramie  Parts per billion
# 1746637  0.196332   2.714286  Wyoming   Laramie  Parts per billion
# 1746641  0.157440   1.857143  Wyoming   Laramie  Parts per billion
# 1746645  0.190995   2.428571  Wyoming   Laramie  Parts per billion
# 1746649  0.173366   2.428571  Wyoming   Laramie  Parts per billion
# 1746653  0.185720   2.714286  Wyoming   Laramie  Parts per billion
# 1746657  0.163125   2.000000  Wyoming   Laramie  Parts per billion
#
#                   O3 Units          SO2 Units           CO Units YYYY-MM Date
# 0        Parts per million  Parts per billion  Parts per million      2000-01
# 4        Parts per million  Parts per billion  Parts per million      2000-01
# 8        Parts per million  Parts per billion  Parts per million      2000-01
# 12       Parts per million  Parts per billion  Parts per million      2000-01
# 16       Parts per million  Parts per billion  Parts per million      2000-01
# 20       Parts per million  Parts per billion  Parts per million      2000-01
# 24       Parts per million  Parts per billion  Parts per million      2000-01
# 28       Parts per million  Parts per billion  Parts per million      2000-01
# 32       Parts per million  Parts per billion  Parts per million      2000-01
# 36       Parts per million  Parts per billion  Parts per million      2000-01
# 40       Parts per million  Parts per billion  Parts per million      2000-01
# 44       Parts per million  Parts per billion  Parts per million      2000-01
# 48       Parts per million  Parts per billion  Parts per million      2000-01
# %%
#new_data['Address'] = raw_data_copy['Address'] we don't need address
new_data['State'] = data_with_county_month['State']
new_data['County'] = data_with_county_month['County']
#new_data['City'] = raw_data_copy['City'] we don't need city
new_data['YYYY-MM Date'] = data_with_county_month['YYYY-MM Date']
new_data['NO2 Units'] = data_with_county_month['NO2 Units']
new_data['O3 Units'] = data_with_county_month['O3 Units']
new_data['SO2 Units'] = data_with_county_month['SO2 Units']
new_data['CO Units'] = data_with_county_month['CO Units']
data_with_county_month_grouped = new_data

# %%
data_with_county_month_grouped = data_with_county_month_grouped.drop_duplicates()

# %%
data_with_county_month_grouped.head()
# Out:
#       NO2 Mean    NO2 AQI   O3 Mean     O3 AQI  SO2 Mean    SO2 AQI   CO Mean  \
# 0    62.018567  90.596774  0.017854  30.145161  4.773079  14.258065  1.638020
# 124  45.279868  78.362069  0.022106  41.275862  3.123268  11.603448  1.139334
# 240  29.607728  52.629032  0.023508  39.129032  3.480222   7.500000  0.809256
# 364  28.736916  57.160000  0.028745  49.840000  1.507525   8.760000  0.918006
# 468   2.872158   5.888889  0.031542  56.703704  1.585462   8.555556  0.775860
#
#         CO AQI    State    County YYYY-MM Date          NO2 Units  \
# 0    33.290323  Arizona  Maricopa      2000-01  Parts per billion
# 124  23.741379  Arizona  Maricopa      2000-02  Parts per billion
# 240  16.080645  Arizona  Maricopa      2000-03  Parts per billion
# 364  18.800000  Arizona  Maricopa      2000-04  Parts per billion
# 468  15.592593  Arizona  Maricopa      2000-05  Parts per billion
#
#               O3 Units          SO2 Units           CO Units
# 0    Parts per million  Parts per billion  Parts per million
# 124  Parts per million  Parts per billion  Parts per million
# 240  Parts per million  Parts per billion  Parts per million
# 364  Parts per million  Parts per billion  Parts per million
# 468  Parts per million  Parts per billion  Parts per million

# %%
# plotting for maricopa
maricopa_month = data_with_county_month_grouped[data_with_county_month_grouped['County'] == 'Maricopa']
maricopa_month['YYYY-MM Date'] = pd.to_datetime(maricopa_month['YYYY-MM Date']) #this makes date YYYY-MM-DD

#Plotting for county above with 100 data points, because there are many dates
fig, ax = plt.subplots(figsize = (12,6))
fig = sns.lineplot(x = "YYYY-MM Date", y = "NO2 Mean", data = maricopa_month.head(100), ax=ax)
x_dates = maricopa_month['YYYY-MM Date'].dt.strftime('%Y-%m').sort_values()
ax.set(xlim = ('1999-12', '2008-07'))
# Out:
# C:\Users\shubh\AppData\Roaming\Python\Python36\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# [(730089.0, 733224.0)]

# %%
month_for_state = data_with_state['Date Local'].str[:7] # series of YYYY-MM
data_with_state_month = data_with_state # make a copy of df with sites and dates
data_with_state_month = data_with_state_month.drop('Date Local', axis = 1) #drop the date column
data_with_state_month['YYYY-MM Date'] = month_for_state # add the new formatted YYYY-MM date
data_with_state_month
# Out:
#           NO2 Mean    NO2 AQI   O3 Mean     O3 AQI  SO2 Mean    SO2 AQI  \
# 0        24.166666  54.750000  0.022021  33.250000  2.094271   7.000000
# 4        22.010417  46.000000  0.014760  25.500000  1.513542   3.250000
# 8        50.419643  81.000000  0.012125  20.500000  3.120833  11.000000
# 12       39.888587  66.500000  0.016084  26.250000  3.104687  10.500000
# 16       52.758333  62.750000  0.009521  17.250000  4.123958  13.250000
# 20       41.003804  67.000000  0.015844  26.250000  3.324405  10.250000
# 24       40.239583  63.250000  0.014760  29.500000  3.944792  13.750000
# 28       43.000000  60.000000  0.011823  23.750000  3.466146  10.250000
# 32       39.708333  60.250000  0.013333  25.750000  3.706250  16.000000
# 36       59.588542  76.500000  0.013604  24.250000  4.718966  16.250000
# 40       55.219697  76.250000  0.014219  27.500000  4.809896  15.250000
# 1746637   4.512943  13.285714  0.028397  31.857143  0.157681   0.142857
# 1746641   3.886157  13.000000  0.031368  36.142857  0.101796   0.142857
# 1746645   7.253667  14.428571  0.033202  40.714286  0.430298   2.142857
# 1746649   5.752590  11.714286  0.033137  40.428571  0.203145   0.285714
# 1746653   4.570259  10.000000  0.037726  43.000000  0.243481   1.142857
# 1746657   3.693504   6.857143  0.035368  37.857143  0.240422   0.285714
#
#           CO Mean     CO AQI    State          NO2 Units           O3 Units  \
# 0        0.605263  14.000000  Arizona  Parts per billion  Parts per million
# 4        0.560764  14.750000  Arizona  Parts per billion  Parts per million
# 8        1.523390  23.500000  Arizona  Parts per billion  Parts per million
# 12       1.136384  20.500000  Arizona  Parts per billion  Parts per million
# 16       1.438542  24.000000  Arizona  Parts per billion  Parts per million
# 20       1.259760  24.500000  Arizona  Parts per billion  Parts per million
# 24       1.282812  26.750000  Arizona  Parts per billion  Parts per million
# 28       1.387500  33.250000  Arizona  Parts per billion  Parts per million
# 32       1.070834  21.000000  Arizona  Parts per billion  Parts per million
# 36       1.660417  33.500000  Arizona  Parts per billion  Parts per million
# 40       1.564855  36.500000  Arizona  Parts per billion  Parts per million
# 44       1.533854  32.500000  Arizona  Parts per billion  Parts per million
# 48       1.885343  33.250000  Arizona  Parts per billion  Parts per million
# 52       1.317188  29.000000  Arizona  Parts per billion  Parts per million
# 56       1.509375  30.250000  Arizona  Parts per billion  Parts per million
# 60       1.001563  31.250000  Arizona  Parts per billion  Parts per million
# 64       1.330208  25.000000  Arizona  Parts per billion  Parts per million
# 68       1.515784  27.500000  Arizona  Parts per billion  Parts per million
# 72       1.530729  27.500000  Arizona  Parts per billion  Parts per million
# 76       1.232102  24.500000  Arizona  Parts per billion  Parts per million
# 80       1.241146  25.000000  Arizona  Parts per billion  Parts per million
# 84       1.109375  27.250000  Arizona  Parts per billion  Parts per million
# 88       1.081250  22.750000  Arizona  Parts per billion  Parts per million
# 92       1.160235  20.750000  Arizona  Parts per billion  Parts per million
# 96       0.789583  18.750000  Arizona  Parts per billion  Parts per million
# 100      0.702400  13.500000  Arizona  Parts per billion  Parts per million
# 104      0.755480  13.500000  Arizona  Parts per billion  Parts per million
# 108      0.925000  15.500000  Arizona  Parts per billion  Parts per million
# 112      1.061979  20.750000  Arizona  Parts per billion  Parts per million
# 116      0.796354  23.000000  Arizona  Parts per billion  Parts per million
# ...           ...        ...      ...                ...                ...
# 1746541  0.223658   3.142857  Wyoming  Parts per billion  Parts per million
# 1746545  0.178959   2.000000  Wyoming  Parts per billion  Parts per million
# 1746549  0.217293   3.142857  Wyoming  Parts per billion  Parts per million
# 1746553  0.201257   2.857143  Wyoming  Parts per billion  Parts per million
# 1746557  0.257863   3.428571  Wyoming  Parts per billion  Parts per million
# 1746561  0.219463   3.285714  Wyoming  Parts per billion  Parts per million
# 1746565  0.218133   3.571429  Wyoming  Parts per billion  Parts per million
# 1746569  0.200409   2.857143  Wyoming  Parts per billion  Parts per million
# 1746573  0.183526   2.571429  Wyoming  Parts per billion  Parts per million
# 1746577  0.168503   2.571429  Wyoming  Parts per billion  Parts per million
# 1746581  0.181339   2.571429  Wyoming  Parts per billion  Parts per million
# 1746585  0.164554   2.142857  Wyoming  Parts per billion  Parts per million
# 1746589  0.185355   2.857143  Wyoming  Parts per billion  Parts per million
# 1746593  0.152948   2.285714  Wyoming  Parts per billion  Parts per million
# 1746597  0.149966   2.000000  Wyoming  Parts per billion  Parts per million
# 1746601  0.183227   2.571429  Wyoming  Parts per billion  Parts per million
# 1746605  0.177290   2.428571  Wyoming  Parts per billion  Parts per million
# 1746609  0.162527   1.714286  Wyoming  Parts per billion  Parts per million
# 1746613  0.151549   1.714286  Wyoming  Parts per billion  Parts per million
# 1746617  0.193081   2.333333  Wyoming  Parts per billion  Parts per million
# 1746621  0.181140   2.285714  Wyoming  Parts per billion  Parts per million
# 1746625  0.178022   2.714286  Wyoming  Parts per billion  Parts per million
# 1746629  0.200910   2.714286  Wyoming  Parts per billion  Parts per million
# 1746633  0.184160   2.714286  Wyoming  Parts per billion  Parts per million
# 1746637  0.196332   2.714286  Wyoming  Parts per billion  Parts per million
# 1746641  0.157440   1.857143  Wyoming  Parts per billion  Parts per million
# 1746645  0.190995   2.428571  Wyoming  Parts per billion  Parts per million
# 1746649  0.173366   2.428571  Wyoming  Parts per billion  Parts per million
# 1746653  0.185720   2.714286  Wyoming  Parts per billion  Parts per million
# 1746657  0.163125   2.000000  Wyoming  Parts per billion  Parts per million
#
#                  SO2 Units           CO Units YYYY-MM Date
# 0        Parts per billion  Parts per million      2000-01
# 4        Parts per billion  Parts per million      2000-01
# 8        Parts per billion  Parts per million      2000-01
# 12       Parts per billion  Parts per million      2000-01
# 16       Parts per billion  Parts per million      2000-01
# 20       Parts per billion  Parts per million      2000-01
# 24       Parts per billion  Parts per million      2000-01
# 28       Parts per billion  Parts per million      2000-01
# 32       Parts per billion  Parts per million      2000-01
# 36       Parts per billion  Parts per million      2000-01
# 40       Parts per billion  Parts per million      2000-01
# 44       Parts per billion  Parts per million      2000-01
# 48       Parts per billion  Parts per million      2000-01
# 52       Parts per billion  Parts per million      2000-01
# 56       Parts per billion  Parts per million      2000-01
# 60       Parts per billion  Parts per million      2000-01
# 64       Parts per billion  Parts per million      2000-01
# 68       Parts per billion  Parts per million      2000-01
# 72       Parts per billion  Parts per million      2000-01
# 76       Parts per billion  Parts per million      2000-01
# 80       Parts per billion  Parts per million      2000-01
# 84       Parts per billion  Parts per million      2000-01
# 88       Parts per billion  Parts per million      2000-01
# 92       Parts per billion  Parts per million      2000-01
# 96       Parts per billion  Parts per million      2000-01
# 100      Parts per billion  Parts per million      2000-01
# 104      Parts per billion  Parts per million      2000-01
# 108      Parts per billion  Parts per million      2000-01
# 112      Parts per billion  Parts per million      2000-01
# 116      Parts per billion  Parts per million      2000-01
# ...                    ...                ...          ...
# 1746541  Parts per billion  Parts per million      2016-03
# 1746545  Parts per billion  Parts per million      2016-03
# 1746549  Parts per billion  Parts per million      2016-03
# 1746553  Parts per billion  Parts per million      2016-03
# 1746557  Parts per billion  Parts per million      2016-03
# 1746561  Parts per billion  Parts per million      2016-03
# 1746565  Parts per billion  Parts per million      2016-03
# 1746569  Parts per billion  Parts per million      2016-03
# 1746573  Parts per billion  Parts per million      2016-03
# 1746577  Parts per billion  Parts per million      2016-03
# 1746581  Parts per billion  Parts per million      2016-03
# 1746585  Parts per billion  Parts per million      2016-03
# 1746589  Parts per billion  Parts per million      2016-03
# 1746593  Parts per billion  Parts per million      2016-03
# 1746597  Parts per billion  Parts per million      2016-03
# 1746601  Parts per billion  Parts per million      2016-03
# 1746605  Parts per billion  Parts per million      2016-03
# 1746609  Parts per billion  Parts per million      2016-03
# 1746613  Parts per billion  Parts per million      2016-03
# 1746617  Parts per billion  Parts per million      2016-03
# 1746621  Parts per billion  Parts per million      2016-03
# 1746625  Parts per billion  Parts per million      2016-03
# 1746629  Parts per billion  Parts per million      2016-03
# 1746633  Parts per billion  Parts per million      2016-03
# 1746637  Parts per billion  Parts per million      2016-03
# 1746641  Parts per billion  Parts per million      2016-03
# 1746645  Parts per billion  Parts per million      2016-03
# 1746649  Parts per billion  Parts per million      2016-03
# 1746653  Parts per billion  Parts per million      2016-03
# 1746657  Parts per billion  Parts per million      2016-03
#
# [146180 rows x 14 columns]

# %%
new_data = data_with_county_month.groupby(['State', 'YYYY-MM Date'])[['NO2 Mean','NO2 AQI','O3 Mean','O3 AQI','SO2 Mean','SO2 AQI','CO Mean','CO AQI']].transform('mean')
# group by state and YYYY-MM date

# %%
#new_data['Address'] = raw_data_copy['Address'] we don't need address
new_data['State'] = data_with_county_month['State']
#new_data['County'] = raw_data_copy['County'] we don't need county
#new_data['City'] = raw_data_copy['City'] we don't need city
new_data['YYYY-MM Date'] = data_with_county_month['YYYY-MM Date']
new_data['NO2 Units'] = data_with_county_month['NO2 Units']
new_data['O3 Units'] = data_with_county_month['O3 Units']
new_data['SO2 Units'] = data_with_county_month['SO2 Units']
new_data['CO Units'] = data_with_county_month['CO Units']
data_with_state_month_grouped = new_data

# %%
data_with_state_month_grouped.shape
# Out:
# (326605, 14)

# %%
data_with_state_month_grouped.drop_duplicates().shape
# Out:
# (5085, 14)

# %%
data_with_state_month_grouped = data_with_state_month_grouped.drop_duplicates()

# %%
data_with_state_month_grouped.head()
# Out:
#       NO2 Mean    NO2 AQI   O3 Mean     O3 AQI  SO2 Mean    SO2 AQI   CO Mean  \
# 0    45.058325  66.811475  0.015735  27.942623  4.057788  12.819672  1.183397
# 124  35.733678  62.421569  0.021390  37.627451  3.048486   9.970588  0.894859
# 240  25.087590  46.940678  0.025990  39.847458  2.680529   6.533898  0.620210
# 364  23.464792  50.880000  0.031152  49.200000  2.047614   8.320000  0.659057
# 468   8.825951  23.793103  0.035240  60.293103  2.195578   8.103448  0.538039
#
#         CO AQI    State YYYY-MM Date          NO2 Units           O3 Units  \
# 0    24.180328  Arizona      2000-01  Parts per billion  Parts per million
# 124  18.127451  Arizona      2000-02  Parts per billion  Parts per million
# 240  11.940678  Arizona      2000-03  Parts per billion  Parts per million
# 364  13.220000  Arizona      2000-04  Parts per billion  Parts per million
# 468  10.568966  Arizona      2000-05  Parts per billion  Parts per million
#
#              SO2 Units           CO Units
# 0    Parts per billion  Parts per million
# 124  Parts per billion  Parts per million
# 240  Parts per billion  Parts per million
# 364  Parts per billion  Parts per million
# 468  Parts per billion  Parts per million

# %%
plot_us_all_time = data_with_state_month_grouped.groupby('YYYY-MM Date')[['NO2 Mean','NO2 AQI','O3 Mean','O3 AQI','SO2 Mean','SO2 AQI','CO Mean','CO AQI']].transform('mean')
plot_us_all_time.head()
# Out:
#       NO2 Mean    NO2 AQI   O3 Mean     O3 AQI  SO2 Mean    SO2 AQI   CO Mean  \
# 0    23.208329  36.226822  0.012585  18.370198  5.912209  20.136601  0.855471
# 124  23.877810  39.449804  0.017599  24.519747  5.552565  20.303287  0.716206
# 240  22.090597  38.578113  0.019009  25.359038  4.346265  17.062555  0.715831
# 364  16.646524  32.479157  0.026991  36.569328  3.694417  16.263526  0.548093
# 468  15.143697  29.889822  0.031351  45.042093  3.658561  15.910729  0.489412
#
#         CO AQI
# 0    15.010010
# 124  12.567007
# 240  12.731174
# 364   9.107890
# 468   7.664918

# %%
#new_data['Address'] = raw_data_copy['Address'] we don't need address
#new_data['State'] = raw_data_copy['State']
#new_data['County'] = raw_data_copy['County'] we don't need county
#new_data['City'] = raw_data_copy['City'] we don't need city
plot_us_all_time['YYYY-MM Date'] = data_with_state_month_grouped['YYYY-MM Date']
plot_us_all_time['NO2 Units'] = data_with_state_month_grouped['NO2 Units']
plot_us_all_time['O3 Units'] = data_with_state_month_grouped['O3 Units']
plot_us_all_time['SO2 Units'] = data_with_state_month_grouped['SO2 Units']
plot_us_all_time['CO Units'] = data_with_state_month_grouped['CO Units']
plot_us_all_time.head()
# Out:
#       NO2 Mean    NO2 AQI   O3 Mean     O3 AQI  SO2 Mean    SO2 AQI   CO Mean  \
# 0    23.208329  36.226822  0.012585  18.370198  5.912209  20.136601  0.855471
# 124  23.877810  39.449804  0.017599  24.519747  5.552565  20.303287  0.716206
# 240  22.090597  38.578113  0.019009  25.359038  4.346265  17.062555  0.715831
# 364  16.646524  32.479157  0.026991  36.569328  3.694417  16.263526  0.548093
# 468  15.143697  29.889822  0.031351  45.042093  3.658561  15.910729  0.489412
#
#         CO AQI YYYY-MM Date          NO2 Units           O3 Units  \
# 0    15.010010      2000-01  Parts per billion  Parts per million
# 124  12.567007      2000-02  Parts per billion  Parts per million
# 240  12.731174      2000-03  Parts per billion  Parts per million
# 364   9.107890      2000-04  Parts per billion  Parts per million
# 468   7.664918      2000-05  Parts per billion  Parts per million
#
#              SO2 Units           CO Units
# 0    Parts per billion  Parts per million
# 124  Parts per billion  Parts per million
# 240  Parts per billion  Parts per million
# 364  Parts per billion  Parts per million
# 468  Parts per billion  Parts per million

# %%
plot_us_all_time = plot_us_all_time.drop_duplicates()

# %%
# plotting for maricopa
plot_us_temp = plot_us_all_time
plot_us_temp['YYYY-MM Date'] = pd.to_datetime(plot_us_temp['YYYY-MM Date']) #this makes date YYYY-MM-DD

#Plotting for county above with 100 data points, because there are many dates
fig, ax = plt.subplots(figsize = (12,6))
fig = sns.lineplot(x = "YYYY-MM Date", y = "NO2 Mean", data = plot_us_temp, ax=ax)
x_dates = plot_us_temp['YYYY-MM Date'].dt.strftime('%Y-%m').sort_values()
ax.set(xlim = ('1999-12', '2016-07'))
# Out:
# [(730089.0, 736146.0)]

# %%
data_with_state.head()
# Out:
#      NO2 Mean  NO2 AQI   O3 Mean  O3 AQI  SO2 Mean  SO2 AQI   CO Mean  CO AQI  \
# 0   24.166666    54.75  0.022021   33.25  2.094271     7.00  0.605263   14.00
# 4   22.010417    46.00  0.014760   25.50  1.513542     3.25  0.560764   14.75
# 8   50.419643    81.00  0.012125   20.50  3.120833    11.00  1.523390   23.50
# 12  39.888587    66.50  0.016084   26.25  3.104687    10.50  1.136384   20.50
# 16  52.758333    62.75  0.009521   17.25  4.123958    13.25  1.438542   24.00
#
#       State  Date Local          NO2 Units           O3 Units  \
# 0   Arizona  2000-01-01  Parts per billion  Parts per million
# 4   Arizona  2000-01-02  Parts per billion  Parts per million
# 8   Arizona  2000-01-03  Parts per billion  Parts per million
# 12  Arizona  2000-01-04  Parts per billion  Parts per million
# 16  Arizona  2000-01-05  Parts per billion  Parts per million
#
#             SO2 Units           CO Units
# 0   Parts per billion  Parts per million
# 4   Parts per billion  Parts per million
# 8   Parts per billion  Parts per million
# 12  Parts per billion  Parts per million
# 16  Parts per billion  Parts per million

# %%
plot_us_year = data_with_state.groupby('Date Local')[['NO2 Mean','NO2 AQI','O3 Mean','O3 AQI','SO2 Mean','SO2 AQI','CO Mean','CO AQI']].transform('mean')
plot_us_year.head()
# Out:
#      NO2 Mean    NO2 AQI   O3 Mean     O3 AQI  SO2 Mean    SO2 AQI   CO Mean  \
# 0   23.294833  39.531829  0.013629  20.251157  7.474980  25.263310  0.975102
# 4   18.013628  30.124579  0.017561  24.668981  6.179340  21.399200  0.735904
# 8   23.236181  37.924769  0.012162  18.761574  5.386359  18.707176  0.796482
# 12  22.116410  36.780093  0.012971  17.916088  4.099343  16.364005  0.747763
# 16  20.044904  34.197917  0.014457  21.581019  3.943910  16.941551  0.739665
#
#        CO AQI
# 0   19.731481
# 4   14.964226
# 8   13.904514
# 12  14.367477
# 16  13.427083

# %%
#new_data['Address'] = raw_data_copy['Address'] we don't need address
#new_data['State'] = raw_data_copy['State']
#new_data['County'] = raw_data_copy['County'] we don't need county
#new_data['City'] = raw_data_copy['City'] we don't need city
plot_us_year['Date Local'] = data_with_state['Date Local']
plot_us_year['NO2 Units'] = data_with_state['NO2 Units']
plot_us_year['O3 Units'] = data_with_state['O3 Units']
plot_us_year['SO2 Units'] = data_with_state['SO2 Units']
plot_us_year['CO Units'] = data_with_state['CO Units']
plot_us_year.head()
# Out:
#      NO2 Mean    NO2 AQI   O3 Mean     O3 AQI  SO2 Mean    SO2 AQI   CO Mean  \
# 0   23.294833  39.531829  0.013629  20.251157  7.474980  25.263310  0.975102
# 4   18.013628  30.124579  0.017561  24.668981  6.179340  21.399200  0.735904
# 8   23.236181  37.924769  0.012162  18.761574  5.386359  18.707176  0.796482
# 12  22.116410  36.780093  0.012971  17.916088  4.099343  16.364005  0.747763
# 16  20.044904  34.197917  0.014457  21.581019  3.943910  16.941551  0.739665
#
#        CO AQI  Date Local          NO2 Units           O3 Units  \
# 0   19.731481  2000-01-01  Parts per billion  Parts per million
# 4   14.964226  2000-01-02  Parts per billion  Parts per million
# 8   13.904514  2000-01-03  Parts per billion  Parts per million
# 12  14.367477  2000-01-04  Parts per billion  Parts per million
# 16  13.427083  2000-01-05  Parts per billion  Parts per million
#
#             SO2 Units           CO Units
# 0   Parts per billion  Parts per million
# 4   Parts per billion  Parts per million
# 8   Parts per billion  Parts per million
# 12  Parts per billion  Parts per million
# 16  Parts per billion  Parts per million

# %%
plot_us_year = plot_us_year.drop_duplicates()

# %%
# new DF for address above
sk = plot_us_year
sk['Date Local'] = pd.to_datetime(sk['Date Local'])

#Plotting for county above with 100 data points, because there are many dates
sns.set(style="whitegrid")
fig, ax = plt.subplots(figsize = (18,6))
sns.lineplot(x = "Date Local", y = "NO2 AQI", data = sk, ci = None, ax=ax, color = "blue", )
sns.lineplot(x = "Date Local", y = "SO2 AQI", data = sk, ci = None, ax=ax, color = "orange")
sns.lineplot(x = "Date Local", y = "O3 AQI", data = sk, ci = None, ax=ax, color = "green")
sns.lineplot(x = "Date Local", y = "CO AQI", data = sk, ci = None, ax=ax, color = "red")
x_dates = sk['Date Local'].dt.strftime('%Y-%m-%d').sort_values()
ax.set(xlim = ('2015-01', '2016-01'), ylim = (0, 65))
plt.legend(labels=['NO2 AQI', 'SO2 AQI', 'O3 AQI', 'CO AQI'])

# %%
# Templates:
#     to aggregate (group) data: 
#         new_data = df.groupby(["cols to group by"])[["cols to be aggregated"]].transform("function to aggregate (such as mean, max, etc)")
    
#     then add appropriate cols to new data:
#         for example:
#                 new_data['Address'] = raw_data_copy['Address']
#                 new_data['State'] = raw_data_copy['State']
#                 new_data['County'] = raw_data_copy['County']
#                 new_data['City'] = raw_data_copy['City']
#                 new_data['YYYY-MM Date'] = data_with_site_month['YYYY-MM Date']
#                 new_data['NO2 Units'] = raw_data_copy['NO2 Units']
#                 new_data['O3 Units'] = raw_data_copy['O3 Units']
#                 new_data['SO2 Units'] = raw_data_copy['SO2 Units']
#                 new_data['CO Units'] = raw_data_copy['CO Units']
#                 grouped_df = new_data
    
#     then drop duplicates because aggregation will produce identical values in "cols to be aggregated":
#         grouped_df = grouped_df.drop_duplicates()
        
#     you can check the change in number of rows by removing duplicates by checking grouped_df.shape before
#     and after dropping
    
#     Plotting:
#         (site/city/county/state)name_month = data_with_(site/city/county/state)_month_grouped[data_with_(site/city/county/state)_month_grouped
#                                                                                                   ['Address/City/County/State'] == 'address/city/county/state name']
#         (site/city/county/state)name_month['Date Local / YYYY-MM Date'] = pd.to_datetime((site/city/county/state)name_month['Date Local / YYYY-MM Date']) #this makes date YYYY-MM-DD
        
#             Barplots:
#                 fig, ax = plt.subplots(figsize = (20,6))
#                 fig = sns.barplot(x = "Date Local / YYYY-MM Date", y = "col to be plotted", data = (site/city/county/state)name_month.head(100), ci = None, ax=ax)
#                 x_dates = (site/city/county/state)name_month['Date Local / YYYY-MM Date'].dt.strftime('%Y-%m-%D / %Y-%m').sort_values()
#                 ax.set_xticklabels(labels=x_dates, rotation=45, ha='right')
            
#             Scatterplots:
#                 fig, ax = plt.subplots(figsize = (12,6))
#                 fig = sns.scatterplot(x = "Date Local / YYYY-MM Date", y = "col to be plotted", data = (site/city/county/state)name_month.head(100), ax=ax)
#                 x_dates = (site/city/county/state)name_month['Date Local / YYYY-MM Date'].dt.strftime('%Y-%m-%D / %Y-%m').sort_values()
#                 ax.set(xlim = ('start date', 'end date'))
                
#             Lineplots:
#                 fig, ax = plt.subplots(figsize = (12,6))
#                 fig = sns.lineplot(x = "Date Local / YYYY-MM Date", y = "col to be plotted", data = maricopa_month.head(100), ax=ax)
#                 x_dates = maricopa_month['Date Local / YYYY-MM Date'].dt.strftime('%Y-%m-%D / %Y-%m').sort_values()
#                 ax.set(xlim = ('start date', 'end date'))
